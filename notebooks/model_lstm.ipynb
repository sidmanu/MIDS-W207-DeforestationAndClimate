# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import math

# ignore TF CPU logs, before importing tensorflow 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'


import tensorflow as tf
import tensorflow.keras as keras 
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.preprocessing import StandardScaler


# Display all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Ignore verbose errors
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# ### Set Seed for consistent reproducibility

# %%
import random as python_random

def reset_seeds(seed_val = 0):
   np.random.seed(seed_val) 
   python_random.seed(seed_val)
   tf.random.set_seed(seed_val)

reset_seeds()

# %% [markdown]
# ### Load combined pre-processed datasets

# %%
train = pd.read_csv('../data/train_monthly.csv',sep='\t')
test = pd.read_csv('../data/test_monthly.csv',sep='\t')
val = pd.read_csv('../data/validation_monthly.csv',sep='\t')

# %% [markdown]
# Check for Nan Values

# %%
missing_values = train.isna().sum()

# Filter and print only the columns with non-zero missing values
non_zero_missing_values = missing_values[missing_values > 0]
print(non_zero_missing_values)
# Out:
# cdsd      1
# dsnd     24
# dyfg    167
# dysd     24
# dyts    167
# emsd     24
# evap    153
# hdsd      7
# mnpn    164
# mxpn    164
# wdmv    153
# dtype: int64

# %%
train.describe()
# Out:
#        Unnamed: 0        cdsd        cldd        dp01        dp10        dp1x  \
# count   167.00000  166.000000  167.000000  167.000000  167.000000  167.000000
# mean     83.00000   12.846386    2.262275    6.185629    4.359281    0.616766
# std      48.35287   15.586605    6.451390    5.215388    4.220178    1.288207
# min       0.00000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      41.50000    0.000000    0.000000    2.000000    1.000000    0.000000
# 50%      83.00000    2.450000    0.000000    5.000000    3.000000    0.000000
# 75%     124.50000   29.000000    0.150000    9.000000    6.500000    1.000000
# max     166.00000   46.700000   40.500000   21.000000   19.000000    8.000000
#
#              dsnd        dsnw        dt00        dt32        dx32        dx70  \
# count  143.000000  167.000000  167.000000  167.000000  167.000000  167.000000
# mean    11.069930    2.730539    0.071856   16.275449    1.161677    9.299401
# std     12.600945    3.611289    0.373342   12.236458    2.217992   12.038850
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    2.000000    0.000000    0.000000
# 50%      4.000000    1.000000    0.000000   21.000000    0.000000    1.000000
# 75%     25.000000    4.000000    0.000000   28.000000    1.000000   21.000000
# max     31.000000   18.000000    3.000000   31.000000   10.000000   31.000000
#
#              dx90  dyfg          dynt          dysd          dysn  dyts  \
# count  167.000000   0.0  1.670000e+02  1.430000e+02  1.670000e+02   0.0
# mean     0.035928   NaN  2.007551e+07  2.006821e+07  2.007552e+07   NaN
# std      0.242780   NaN  4.050731e+04  3.913879e+04  4.050630e+04   NaN
# min      0.000000   NaN  2.001012e+07  2.001013e+07  2.001013e+07   NaN
# 25%      0.000000   NaN  2.004066e+07  2.003567e+07  2.004067e+07   NaN
# 50%      0.000000   NaN  2.007123e+07  2.006123e+07  2.007122e+07   NaN
# 75%      0.000000   NaN  2.011066e+07  2.009117e+07  2.011067e+07   NaN
# max      2.000000   NaN  2.014123e+07  2.014122e+07  2.014122e+07   NaN
#
#                dyxp          dyxt        emnt         emsd        emsn  \
# count  1.670000e+02  1.670000e+02  167.000000   143.000000  167.000000
# mean   2.007551e+07  2.007551e+07   -6.461677   339.244755  128.221557
# std    4.050649e+04  4.050703e+04    6.873905   452.926559  169.941712
#
#        tc_loss_ha_Philippines  tc_loss_ha_Poland  tc_loss_ha_Portugal  \
# count              167.000000         167.000000           167.000000
# mean             55528.449102       47872.724551         41258.413174
# std              21921.082909       16207.904367         11543.825005
# min              32309.000000       19066.000000         24405.000000
# 25%              35165.000000       35015.000000         33615.000000
# 50%              49782.000000       46926.000000         38934.000000
# 75%              60890.000000       56650.000000         51884.000000
# max             102649.000000       82379.000000         60259.000000
#
#        tc_loss_ha_Puerto Rico  tc_loss_ha_Republic of Congo  \
# count              167.000000                    167.000000
# mean              1054.520958                  30172.520958
# std                242.382821                  16019.425260
# min                595.000000                  13833.000000
# 25%                871.000000                  18853.000000
# 50%               1194.000000                  24310.000000
# 75%               1243.000000                  32144.000000
# max               1324.000000                  72891.000000
#
#        tc_loss_ha_Reunion  tc_loss_ha_Romania  tc_loss_ha_Russia  \
# count          167.000000          167.000000       1.670000e+02
# mean           407.958084        18881.185629       3.016008e+06
# std            443.016323         7054.642637       1.157487e+06
# min              0.000000         9428.000000       1.589993e+06
# 25%             29.000000        16177.000000       2.111641e+06
# 50%            225.000000        17535.000000       3.021488e+06
# 75%            629.000000        19418.000000       3.521018e+06
# max           1653.000000        38082.000000       5.391244e+06
#
#        tc_loss_ha_Rwanda  tc_loss_ha_Saint Kitts and Nevis  \
# count         167.000000                        167.000000
# mean         1418.862275                         20.149701
# std           656.601307                         11.220479
# min           746.000000                          4.000000
# 25%           941.000000                         12.000000
# 50%          1101.000000                         20.000000
# 75%          1517.000000                         25.000000
# max          2889.000000                         46.000000
#
#        tc_loss_ha_Saint Lucia  tc_loss_ha_Saint Pierre and Miquelon  \
# count              167.000000                            167.000000
# mean                51.065868                              0.431138
# std                 24.510912                              1.300968
# min                 11.000000                              0.000000
# 25%                 36.000000                              0.000000
# 50%                 49.000000                              0.000000
# 75%                 62.000000                              0.000000
# max                100.000000                              5.000000
#
#        tc_loss_ha_Saint Vincent and the Grenadines  tc_loss_ha_Saint-Martin  \
# count                                   167.000000               167.000000
# mean                                     22.095808                 3.155689
# std                                      15.326657                 2.270757
# min                                       7.000000                 1.000000
# 25%                                      10.000000                 2.000000
# 50%                                      17.000000                 3.000000
# 75%                                      30.000000                 3.000000
# max                                      66.000000                10.000000
#
#        tc_loss_ha_San Marino  tc_loss_ha_Senegal  tc_loss_ha_Serbia  \
# count             167.000000          167.000000         167.000000
# mean                0.143713          156.443114        2415.221557
# std                 0.351853          101.660290         894.754684
# min                 0.000000           38.000000         865.000000
# 25%                 0.000000           72.000000        1891.000000
# 50%                 0.000000          128.000000        2380.000000
# 75%                 0.000000          172.000000        2798.000000
# max                 1.000000          375.000000        4388.000000
#
#        tc_loss_ha_Seychelles  tc_loss_ha_Sierra Leone  tc_loss_ha_Singapore  \
# count             167.000000               167.000000            167.000000
# mean                0.287425             39226.215569             76.766467
# std                 0.592135             52787.318323             52.107737
# min                 0.000000              4020.000000             19.000000
# 25%                 0.000000              9099.000000             35.000000
# 50%                 0.000000             20925.000000             74.000000
# 75%                 0.000000             30546.000000             92.000000
# max                 2.000000            170278.000000            191.000000
#
#        tc_loss_ha_Sint Maarten  tc_loss_ha_Slovakia  tc_loss_ha_Slovenia  \
# count               167.000000           167.000000           167.000000
# mean                  1.868263         10419.784431          1576.203593
# std                   1.554437          6566.507304          1187.133982
# min                   0.000000          3750.000000           528.000000
# 25%                   0.000000          4625.000000           724.000000
# 50%                   2.000000          9170.000000          1272.000000
# 75%                   3.000000         13466.000000          1951.000000
# max                   5.000000         27674.000000          5389.000000
#
#        tc_loss_ha_Solomon Islands  tc_loss_ha_Somalia  \
# count                  167.000000          167.000000
# mean                  6497.257485          221.053892
# std                   3613.171747           75.413659
# min                   2187.000000          105.000000
# 25%                   3866.000000          140.000000
# 50%                   5861.000000          250.000000
# 75%                   8171.000000          272.000000
# max                  16939.000000          339.000000
#
#        tc_loss_ha_South Africa  tc_loss_ha_South Korea  \
# count               167.000000              167.000000
# mean              74228.724551            10534.053892
# std               17788.099587             3964.522575
# min               47105.000000             3611.000000
# 25%               61759.000000             8096.000000
# 50%               72602.000000            10148.000000
# 75%               84897.000000            14022.000000
# max              104943.000000            16416.000000
#
#        tc_loss_ha_South Sudan  tc_loss_ha_Spain  tc_loss_ha_Sri Lanka  \
# count              167.000000        167.000000            167.000000
# mean              7375.167665      54918.652695           8275.071856
# std               2485.755495      16883.213495           4054.066623
# min               2063.000000      23315.000000           3149.000000
# 25%               4931.000000      39326.000000           4682.000000
# 50%               8149.000000      60256.000000           7730.000000
# 75%               9012.000000      67545.000000          12350.000000
# max              10566.000000      80496.000000          14737.000000
#
#        tc_loss_ha_Sudan  tc_loss_ha_Suriname  tc_loss_ha_Swaziland  \
# count        167.000000           167.000000            167.000000
# mean          59.748503          7139.401198           5581.149701
# std           63.117286          4619.038733           2224.814376
# min            4.000000          3404.000000           2622.000000
# 25%           13.000000          3689.000000           3801.000000
# 50%           27.000000          5423.000000           4960.000000
# 75%           81.000000          7511.000000           6660.000000
# max          205.000000         19502.000000          10654.000000
#
#        tc_loss_ha_Sweden  tc_loss_ha_Switzerland  tc_loss_ha_Syria  \
# count         167.000000              167.000000        167.000000
# mean       214991.173653             1765.736527        878.652695
# std         52218.089471              822.894672       1337.202474
# min         92619.000000              433.000000        107.000000
# 25%        182858.000000             1165.000000        148.000000
# 50%        208258.000000             1852.000000        281.000000
# 75%        249126.000000             2274.000000        958.000000
# max        293724.000000             3830.000000       5371.000000
#
#        tc_loss_ha_São Tomé and Príncipe  tc_loss_ha_Taiwan  \
# count                        167.000000         167.000000
# mean                           5.532934        2021.461078
# std                           19.945040        1775.703003
# min                            0.000000         953.000000
# 25%                            0.000000        1125.000000
# 50%                            0.000000        1461.000000
# 75%                            0.000000        2077.000000
# max                           77.000000        8162.000000
#
#        tc_loss_ha_Tajikistan  tc_loss_ha_Tanzania  tc_loss_ha_Thailand  \
# count             167.000000           167.000000           167.000000
# mean               24.293413        123833.281437         92837.916168
# std                15.341224         40590.270162         28790.313776
# min                 1.000000         66893.000000         36102.000000
# 25%                14.000000         85081.000000         80143.000000
# 50%                26.000000        121685.000000         91835.000000
# 75%                33.000000        154433.000000        114508.000000
# max                62.000000        198228.000000        137615.000000
#
#        tc_loss_ha_Timor-Leste  tc_loss_ha_Togo  \
# count              167.000000       167.000000
# mean              1479.443114      2317.089820
# std                736.398985      1159.955342
# min                463.000000       514.000000
# 25%                691.000000      1688.000000
# 50%               1556.000000      2054.000000
# 75%               1887.000000      2776.000000
# max               2929.000000      5580.000000
#
#        tc_loss_ha_Trinidad and Tobago  tc_loss_ha_Tunisia  tc_loss_ha_Turkey  \
# count                      167.000000          167.000000         167.000000
# mean                      1242.832335          974.862275       24178.682635
# std                        716.593966          686.394017        3778.971676
# min                        375.000000          231.000000       17008.000000
# 25%                        726.000000          354.000000       22005.000000
# 50%                       1109.000000          878.000000       25344.000000
# 75%                       1569.000000         1415.000000       28108.000000
# max                       3407.000000         2385.000000       28978.000000
#
#        tc_loss_ha_Turkmenistan  tc_loss_ha_Turks and Caicos Islands  \
# count               167.000000                           167.000000
# mean                 33.862275                            28.802395
# std                  31.914403                            29.916397
# min                   0.000000                             5.000000
# 25%                   9.000000                             8.000000
# 50%                  29.000000                            11.000000
# 75%                  46.000000                            38.000000
# max                 105.000000                           106.000000
#
#        tc_loss_ha_Uganda  tc_loss_ha_Ukraine  tc_loss_ha_United Kingdom  \
# count         167.000000          167.000000                 167.000000
# mean        32565.071856        45807.658683               23341.191617
# std         14883.627485        10793.601698                9796.670219
# min         10841.000000        27077.000000                1875.000000
# 25%         23293.000000        37712.000000               20112.000000
# 50%         29172.000000        47187.000000               23244.000000
# 75%         36926.000000        53016.000000               30372.000000
# max         65067.000000        64266.000000               37710.000000
#
#        tc_loss_ha_United States  \
# count              1.670000e+02
# mean               2.085299e+06
# std                3.892076e+05
# min                1.608981e+06
# 25%                1.736445e+06
# 50%                1.964094e+06
# 75%                2.435128e+06
# max                2.746257e+06
#
#        tc_loss_ha_United States Minor Outlying Islands  tc_loss_ha_Uruguay  \
# count                                       167.000000          167.000000
# mean                                          7.401198        18843.988024
# std                                          21.587608         7022.608385
# min                                           0.000000         6870.000000
# 25%                                           0.000000        15126.000000
# 50%                                           0.000000        19280.000000
# 75%                                           2.000000        23597.000000
# max                                          84.000000        31388.000000
#
#        tc_loss_ha_Uzbekistan  tc_loss_ha_Vanuatu  tc_loss_ha_Venezuela  \
# count             167.000000          167.000000            167.000000
# mean               82.227545          420.095808          99808.347305
# std                83.816472          328.028783          19976.281502
# min                21.000000          108.000000          64520.000000
# 25%                33.000000          194.000000          87229.000000
# 50%                53.000000          254.000000          94967.000000
# 75%                83.000000          607.000000         114347.000000
# max               295.000000         1111.000000         142406.000000
#
#        tc_loss_ha_Vietnam  tc_loss_ha_Virgin Islands, U.S.  tc_loss_ha_Zambia  \
# count          167.000000                       167.000000         167.000000
# mean        110851.952096                        43.562874       74128.407186
# std          51963.422468                        29.635445       41513.487564
# min          43008.000000                        20.000000       28488.000000
# 25%          73881.000000                        21.000000       41955.000000
# 50%         102211.000000                        33.000000       57518.000000
# 75%         137716.000000                        50.000000      115221.000000
# max         217342.000000                       123.000000      173984.000000
#
#        tc_loss_ha_Zimbabwe  tc_loss_ha_Åland  tc_loss_ha_average
# count           167.000000        167.000000          167.000000
# mean          10126.425150        532.395210        78075.222927
# std            3600.247044        287.625613        11954.417614
# min            5435.000000        100.000000        56587.483051
# 25%            8016.000000        278.000000        71998.762712
# 50%            9300.000000        510.000000        76687.677966
# 75%           11749.000000        676.000000        84358.978814
# max           19402.000000       1292.000000       100562.338983

# %% [markdown]
# Check tavg data in Training data

# %%
train.loc[:,['date','tavg','tmin','tmax']][:13]
# Out:
#        date   tavg  tmin   tmax
# 0   2001-01  -1.50 -7.28   4.28
# 1   2001-02  -1.50 -6.60   3.60
# 2   2001-03   3.41 -2.42   9.25
# 3   2001-04   2.91 -3.38   9.21
# 4   2001-05  11.98  3.67  20.29
# 5   2001-06  13.97  5.22  22.72
# 6   2001-07  16.35  7.69  25.02
# 7   2001-08  17.96  8.41  27.52
# 8   2001-09  14.68  6.11  23.25
# 9   2001-10  10.94  2.72  19.15
# 10  2001-11   3.93 -1.73   9.60
# 11  2001-12  -1.02 -5.68   3.64
# 12  2002-01  -2.06 -7.93   3.80

# %%
train.loc[:,['date','tavg']][-5:]
# Out:
#         date   tavg
# 162  2014-08  16.41
# 163  2014-09  14.51
# 164  2014-10   9.43
# 165  2014-11   4.45
# 166  2014-12   0.91

# %% [markdown]
# So we have monthly data available from 2001 Jan to 2014 Dec. Now let's see Test data.

# %%
test.loc[:,['date','tavg']]
# Out:
#        date   tavg
# 0   2019-01  -0.10
# 1   2019-02  -3.52
# 2   2019-03   0.08
# 3   2019-04   5.30
# 4   2019-05   6.32
# 5   2019-06  13.09
# 6   2019-07  16.18
# 7   2019-08  16.84
# 8   2019-09  11.97
# 9   2019-10   5.37
# 10  2019-11   3.03
# 11  2019-12  -0.34
# 12  2020-01  -0.18
# 13  2020-02   0.84
# 14  2020-03   0.05
# 15  2020-04   4.67
# 16  2020-05   8.87
# 17  2020-06  12.42
# 18  2020-07  16.83
# 19  2020-08  18.04
# 20  2020-09  14.59
# 21  2020-10  10.02
# 22  2020-11   2.02
# 23  2020-12  -0.13
# 24  2021-01  -0.98
# 25  2021-02  -0.55
# 26  2021-03   0.35
# 27  2021-04   5.31
# 28  2021-05   8.89
# 29  2021-06  16.23
# 30  2021-07  19.94
# 31  2021-08  17.01
# 32  2021-09  14.07
# 33  2021-10   5.76
# 34  2021-11   4.33
# 35  2021-12  -1.23
# 36  2022-01  -1.78
# 37  2022-02  -0.99
# 38  2022-03   2.76
# 39  2022-04   3.74
# 40  2022-05   7.31
# 41  2022-06  12.52
# 42  2022-07  17.64
# 43  2022-08  18.01
# 44  2022-09  14.84
# 45  2022-10   8.98
# 46  2022-11  -0.61
# 47  2022-12  -2.27
# 48  2023-01  -3.25
# 49  2023-02  -3.19
# 50  2023-03  -3.66
# 51  2023-04   1.95
# 52  2023-05   7.73
# 53  2023-06  11.03
# 54  2023-07  17.53
# 55  2023-08  15.58
# 56  2023-09  11.83
# 57  2023-10   7.46
# 58  2023-11   2.71
# 59  2023-12   0.68

# %% [markdown]
# ### Check distribution of Average Temperatures

# %%
import seaborn as sns


plt.figure(figsize=(15, 5))
sns.histplot(train['tavg'],bins=[i for i in range(-10,61,1)], kde=False)
plt.title("Distribution of Temperatures")
plt.grid()
plt.show()

# %% [markdown]
# The distribution is not normal but doens't have much skew.

# %%
df = train


def normalize_columns(df, columns_to_normalize):
    """
    Method to normalize columns passed.
    Adds a new column <column_name>_scaled
    """

    for column in columns_to_normalize:
        feature_scaled = (df[column] - df[column].mean()) / df[column].std()
        scaled_column_name = "{}_scaled".format(column)
        df[scaled_column_name] = feature_scaled

    return df 


columns_to_normalize = ['tc_loss_ha_average', 'tc_loss_ha_United States','tavg','tmin','tmax']
train = normalize_columns(train, columns_to_normalize)
test = normalize_columns(test, columns_to_normalize)
val = normalize_columns(val, columns_to_normalize)

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'date', 'cdsd', 'cldd', 'dp01', 'dp10', 'dp1x', 'dsnd',
#        'dsnw', 'dt00',
#        ...
#        'tc_loss_ha_Virgin Islands, U.S.', 'tc_loss_ha_Zambia',
#        'tc_loss_ha_Zimbabwe', 'tc_loss_ha_Åland', 'tc_loss_ha_average',
#        'tc_loss_ha_average_scaled', 'tc_loss_ha_United States_scaled',
#        'tavg_scaled', 'tmin_scaled', 'tmax_scaled'],
#       dtype='object', length=1140)

# %%
def add_month_and_sin_columns(data):

    # Convert date column to datetime
    data['date'] = pd.to_datetime(data['date'], format='%Y-%m')

    # Extract month from date
    data['month'] = data['date'].dt.month
    data['year'] = data['date'].dt.year

    # Apply sine and cosine transformations to the month
    data['month_sin'] = np.sin(2 * np.pi * data['month'] / 12)
    data['month_cos'] = np.cos(2 * np.pi * data['month'] / 12)

    return data



train = add_month_and_sin_columns(train)
test = add_month_and_sin_columns(test)
val = add_month_and_sin_columns(val)

# %%
def plot_values(df):
    fig, ax = plt.subplots(figsize=(14, 8))  # Corrected here
    
    # Interpolation
    x = df['date']
    y = df['tavg']
    
    
    ax.plot(x, y, color='b')  
    ax.set_title('Average Temperature for first 2 years')
    ax.set_xlabel('Time')
    ax.set_ylabel('TAVG')
    ax.axhline(y=0, color='r', linestyle='--',  label='Zero Line')  # Add horizontal line at y = 0
    plt.xticks(rotation=45, ha='right')

    plt.show()



plot_values(train[:24])

# %% [markdown]
# ### Add Plotly plot so we can  hover over it

# %%
import plotly.express as px

fig = px.line(train, x='date', y='tavg', title='Average Monthly Temperatures Over Time', labels={'tavg': 'Average Temperature in Celsius', 'date': 'Date'})
fig.show()

# %% [markdown]
# ### Non-Time series model using Linear Regression

# %%
linear_regression_features = ['snow','dp10']

X_train = train[linear_regression_features]
y_train = train[['tavg']]


X_test = test[linear_regression_features]
y_test = test[['tavg']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error



# Linear Regression Model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt


# Predictions
y_pred = model.predict(X_test)

# Evaluation
rmse = math.sqrt(mean_squared_error(y_test, y_pred))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 5.1301237114264095

# %%
y_test.head()
# Out:
#    tavg
# 0 -0.10
# 1 -3.52
# 2  0.08
# 3  5.30
# 4  6.32

# %%
def plot_predictions(actual, predicted, xlabel, ylabel, title):
    plt.plot(actual,label='Actual average temperatures')
    plt.plot(predicted, label='Predicted average temperatures')

    plt.xlabel(xlabel)
    plt.title(title)
    plt.ylabel(ylabel)
    plt.legend()
    plt.show()




def plot_predictions_train_test(actual_train, predicted_train, actual_test, predicted_test, xlabel, ylabel, title):
    fig, ax = plt.subplots(1, 2, figsize=(14, 7), sharey=True)

    # Plot training data
    ax[0].plot(actual_train, label='Actual average temperatures', color='blue')
    ax[0].plot(predicted_train, label='Predicted average temperatures', color='red', linestyle='--')
    ax[0].set_title('Training Data')
    ax[0].set_xlabel(xlabel)
    ax[0].set_ylabel(ylabel)
    ax[0].legend()

    # Plot test data
    ax[1].plot(actual_test, label='Actual average temperatures', color='blue')
    ax[1].plot(predicted_test, label='Predicted average temperatures', color='red', linestyle='--')
    ax[1].set_title('Test Data')
    ax[1].set_xlabel(xlabel)
    ax[1].legend()

    # Set the main title for the entire figure
    fig.suptitle(title)

    plt.show()


plot_predictions(y_test, y_pred,"Time","Average Temperature","Linear Regression without time series using test data")

# %%
# Convert data to sequences to make Supervised learning possible

def create_sequences(data, window_size, seq_features, target_variable):
    """_summary_

    Args:
        data (_type_): test/train/validation data
        window_size (_type_): Number of preceding months in training set that will predict the target variable
        seq_features (_type_): features selected in the training data (which includes the target variable)
        target_variable (_type_): The variable to be predicted
    Returns:
        _type_: (X, y) where shape of X is (len(data) - window_size, window_size, seq_features) and shape of y is (window_size, 1)
    """
    xs, ys = [], []
    for i in range(len(data) - window_size):
        x = data[i:i+window_size] [seq_features].values
        y = data[i+window_size:i+window_size+1][target_variable].values # pick 1 row after
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)


# Splits train, test and val data into sequential datasets, suitable for Time Series analysis
def create_sequential_datasets(train, test, val, window_size, lstm_features, target_variable):

    X_seq_train, y_seq_train = create_sequences(train, window_size,lstm_features,target_variable)
    X_seq_test, y_seq_test = create_sequences(test, window_size,lstm_features, target_variable)
    X_seq_val, y_seq_val = create_sequences(val, window_size,lstm_features, target_variable)

    return X_seq_train, y_seq_train, X_seq_test, y_seq_test, X_seq_val, y_seq_val

# %% [markdown]
# #### Test the functionality of create_sequences()

# %%
X_seq_train, y_seq_train = create_sequences(train, window_size=12,seq_features=['tavg','month','year','snow'],target_variable='tavg')

X_seq_train[:1], y_seq_train[:1]
# Out:
# (array([[[-1.500e+00,  1.000e+00,  2.001e+03,  6.610e+02],
#          [-1.500e+00,  2.000e+00,  2.001e+03,  1.589e+03],
#          [ 3.410e+00,  3.000e+00,  2.001e+03,  1.780e+02],
#          [ 2.910e+00,  4.000e+00,  2.001e+03,  5.800e+02],
#          [ 1.198e+01,  5.000e+00,  2.001e+03,  0.000e+00],
#          [ 1.397e+01,  6.000e+00,  2.001e+03,  0.000e+00],
#          [ 1.635e+01,  7.000e+00,  2.001e+03,  0.000e+00],
#          [ 1.796e+01,  8.000e+00,  2.001e+03,  0.000e+00],
#          [ 1.468e+01,  9.000e+00,  2.001e+03,  0.000e+00],
#          [ 1.094e+01,  1.000e+01,  2.001e+03,  0.000e+00],
#          [ 3.930e+00,  1.100e+01,  2.001e+03,  3.170e+02],
#          [-1.020e+00,  1.200e+01,  2.001e+03,  1.816e+03]]]),
#  array([[-2.06]]))

# %%
train[['date','tavg']].head(13)
# Out:
#          date   tavg
# 0  2001-01-01  -1.50
# 1  2001-02-01  -1.50
# 2  2001-03-01   3.41
# 3  2001-04-01   2.91
# 4  2001-05-01  11.98
# 5  2001-06-01  13.97
# 6  2001-07-01  16.35
# 7  2001-08-01  17.96
# 8  2001-09-01  14.68
# 9  2001-10-01  10.94
# 10 2001-11-01   3.93
# 11 2001-12-01  -1.02
# 12 2002-01-01  -2.06

# %%
print(train[train['date'] < '2002-01-01']['tavg'], train[train['date'] == '2002-01-01']['tavg'])
# Out:
# 0     -1.50
# 1     -1.50
# 2      3.41
# 3      2.91
# 4     11.98
# 5     13.97
# 6     16.35
# 7     17.96
# 8     14.68
# 9     10.94
# 10     3.93
# 11    -1.02
# Name: tavg, dtype: float64 12   -2.06
# Name: tavg, dtype: float64

# %%
def build_model(input_shape, hidden_layer_sizes, lstm_layer_sizes, activation, learning_rate, loss):

    model = keras.Sequential() 

    #model.add(keras.layers.Flatten())

    for lstm_layer_size in lstm_layer_sizes[:-1]:
        model.add(keras.layers.LSTM(lstm_layer_size, input_shape=input_shape, return_sequences=True)) #return seq = True 
        model.add(keras.layers.Dropout(0.2)),

    model.add(keras.layers.LSTM(lstm_layer_sizes[-1], return_sequences=False)), # return seq = False for last layer
    model.add(keras.layers.Dropout(0.2)),

    for hidden_layer_size in hidden_layer_sizes:
        model.add(keras.layers.Dense(units=hidden_layer_size, activation=activation))

    # last layer is dense for regression output
    model.add(keras.layers.Dense(1))

    if loss == 'rmse':
        loss = rmse

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss=loss)
    model.summary()

    return model 

from tensorflow.keras import backend as K

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))


def train_and_evaluate_model(selected_features, hidden_layer_sizes, lstm_layer_sizes, window_size, num_epochs, batch_size, learning_rate, loss='rmse'):


    X_seq_train, y_seq_train, X_seq_test, y_seq_test, X_seq_val, y_seq_val = create_sequential_datasets(train, test, val, window_size=window_size, lstm_features=selected_features, 
                                                                                                        target_variable='tavg')
    
    #print("X_seq_train shape", X_seq_train.shape)
    #print("Y_seq_train shape", y_seq_train.shape)
    #print("X_seq_test shape", X_seq_test.shape)
    #print("Y_seq_test shape", y_seq_test.shape)

    
    input_shape = (X_seq_train.shape[1], X_seq_train.shape[2])

    # Build the model 
    model = build_model(input_shape, hidden_layer_sizes, lstm_layer_sizes, activation='relu', learning_rate=learning_rate, loss=loss) 


    # Define callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Train the model, also pass in the validation dataset
    history = model.fit(X_seq_train, y_seq_train, batch_size = batch_size, epochs=num_epochs, validation_data=(X_seq_val, y_seq_val), callbacks=[early_stopping])
    #history = model.fit(X_seq_train, y_seq_train, batch_size=batch_size, epochs=num_epochs, validation_split=0.2, callbacks=[early_stopping])


    # Retrieve the testing metrics (after each test epoch) and the final validation
        # accuracy.
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    plt.plot(train_loss, label='train loss')
    plt.plot(val_loss, label='validation loss')
    plt.xticks(range(num_epochs))
    plt.xlabel('test epochs')
    plt.legend()
    plt.show()

    print('At last epoch, training loss: %1.4f' %train_loss[-1])
    print('At last epoch, Validation loss: %1.4f' %val_loss[-1])


    # Predictions from training data
    y_pred_model_train = model.predict(X_seq_train)
    #plot_predictions(y_seq_train, y_pred_model_train,"Time","Snowfall","LSTM model with features {} with Training Data".format(selected_features))


    # Predictions with test data
    y_pred_model_test = model.predict(X_seq_test)
    #plot_predictions(y_seq_test, y_pred_model_test,"Time","Snowfall","LSTM model with features {} with Test Data".format(selected_features))

    plot_predictions_train_test(y_seq_train, y_pred_model_train, y_seq_test, y_pred_model_test, "Time", "Average Temperature", "{}".format(selected_features))

    train_loss = model.evaluate(X_seq_train, y_seq_train)
    print("Train Loss:", train_loss )

    test_loss = model.evaluate(X_seq_test, y_seq_test)
    print("Test Loss:", test_loss )


    return model

# %% [markdown]
# ### Model 1: LSTM Model with Average Temperature  & Month as features

# %%
model1 = train_and_evaluate_model(['month','tavg'], hidden_layer_sizes=[4],lstm_layer_sizes=[8,4], window_size=12, num_epochs=30, batch_size=8, learning_rate=0.01)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 8)             352
#
#  dropout (Dropout)           (None, 12, 8)             0
#
#  lstm_1 (LSTM)               (None, 4)                 208
#
#  dropout_1 (Dropout)         (None, 4)                 0
#
#  dense (Dense)               (None, 4)                 20
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 585
# Trainable params: 585
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 20/20 [==============================] - 7s 83ms/step - loss: 8.4367 - val_loss: 7.9484
# Epoch 2/30
# 20/20 [==============================] - 0s 12ms/step - loss: 7.1992 - val_loss: 6.8241
# Epoch 3/30
# 20/20 [==============================] - 0s 10ms/step - loss: 6.5774 - val_loss: 6.5249
# Epoch 4/30
# 20/20 [==============================] - 0s 10ms/step - loss: 6.2322 - val_loss: 5.9112
# Epoch 5/30
# 20/20 [==============================] - 0s 10ms/step - loss: 5.7392 - val_loss: 4.9616
# Epoch 6/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.8391 - val_loss: 3.9948
# Epoch 7/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.1141 - val_loss: 3.3318
# Epoch 8/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.5633 - val_loss: 2.9063
# Epoch 9/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.8102 - val_loss: 2.8483
# Epoch 10/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.7560 - val_loss: 2.7016
# Epoch 11/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4847 - val_loss: 2.5086
# Epoch 12/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2583 - val_loss: 2.7651
# Epoch 13/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.3065 - val_loss: 2.4255
# Epoch 14/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.5668 - val_loss: 2.3013
# Epoch 15/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2142 - val_loss: 2.3116
# Epoch 16/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.6496 - val_loss: 2.2167
# Epoch 17/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2748 - val_loss: 2.2122
# Epoch 18/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2778 - val_loss: 2.2516
# Epoch 19/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2981 - val_loss: 2.1426
# Epoch 20/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4970 - val_loss: 2.1900
# Epoch 21/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2069 - val_loss: 2.4314
# Epoch 22/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0582 - val_loss: 2.2629
# Epoch 23/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2848 - val_loss: 2.0744
# Epoch 24/30
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9854 - val_loss: 2.3285
# Epoch 25/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2008 - val_loss: 2.0306
# Epoch 26/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.3623 - val_loss: 2.1220
# Epoch 27/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1150 - val_loss: 2.1344
# Epoch 28/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2079 - val_loss: 1.8909
# Epoch 29/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0857 - val_loss: 1.9364
# Epoch 30/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0665 - val_loss: 1.8943
# At last epoch, training loss: 3.0665
# At last epoch, Validation loss: 1.8943
# 5/5 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step - loss: 2.0917
# Train Loss: 2.0917346477508545
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3130
# Test Loss: 2.313040018081665

# %% [markdown]
# ### Model 2: Month, Tavg, Prcp

# %%
model2 = train_and_evaluate_model(['month','tavg','prcp'], hidden_layer_sizes=[4],lstm_layer_sizes=[8,4], window_size=12, num_epochs=50, batch_size=8, learning_rate=0.01)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 12, 8)             384
#
#  dropout_2 (Dropout)         (None, 12, 8)             0
#
#  lstm_3 (LSTM)               (None, 4)                 208
#
#  dropout_3 (Dropout)         (None, 4)                 0
#
#  dense_2 (Dense)             (None, 4)                 20
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 617
# Trainable params: 617
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 20/20 [==============================] - 7s 77ms/step - loss: 8.5667 - val_loss: 8.1124
# Epoch 2/50
# 20/20 [==============================] - 0s 11ms/step - loss: 7.2215 - val_loss: 6.7422
# Epoch 3/50
# 20/20 [==============================] - 0s 10ms/step - loss: 6.6082 - val_loss: 6.5034
# Epoch 4/50
# 20/20 [==============================] - 0s 10ms/step - loss: 6.2592 - val_loss: 6.0553
# Epoch 5/50
# 20/20 [==============================] - 0s 10ms/step - loss: 5.9073 - val_loss: 5.3205
# Epoch 6/50
# 20/20 [==============================] - 0s 10ms/step - loss: 5.3756 - val_loss: 4.6489
# Epoch 7/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.3694 - val_loss: 3.8792
# Epoch 8/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.9403 - val_loss: 3.2717
# Epoch 9/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.9468 - val_loss: 2.9833
# Epoch 10/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.5817 - val_loss: 2.6925
# Epoch 11/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.8322 - val_loss: 2.6154
# Epoch 12/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.3120 - val_loss: 2.8638
# Epoch 13/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4339 - val_loss: 3.0786
# Epoch 14/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4201 - val_loss: 2.8930
# Epoch 15/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.6611 - val_loss: 3.1101
# Epoch 16/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.9168 - val_loss: 2.9392
# At last epoch, training loss: 3.9168
# At last epoch, Validation loss: 2.9392
# 5/5 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step - loss: 2.6125
# Train Loss: 2.6124634742736816
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9013
# Test Loss: 2.901310682296753

# %%
model3_features=['month','tavg','tmax','tmin']
model3 = train_and_evaluate_model(model3_features, hidden_layer_sizes=[4],lstm_layer_sizes=[8,4], window_size=12, num_epochs=30, batch_size=8, learning_rate=0.01)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 12, 8)             416
#
#  dropout_4 (Dropout)         (None, 12, 8)             0
#
#  lstm_5 (LSTM)               (None, 4)                 208
#
#  dropout_5 (Dropout)         (None, 4)                 0
#
#  dense_4 (Dense)             (None, 4)                 20
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 649
# Trainable params: 649
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 20/20 [==============================] - 7s 78ms/step - loss: 8.1724 - val_loss: 7.7209
# Epoch 2/30
# 20/20 [==============================] - 0s 11ms/step - loss: 6.9834 - val_loss: 6.4868
# Epoch 3/30
# 20/20 [==============================] - 0s 11ms/step - loss: 5.9218 - val_loss: 5.1614
# Epoch 4/30
# 20/20 [==============================] - 0s 11ms/step - loss: 4.6886 - val_loss: 3.8412
# Epoch 5/30
# 20/20 [==============================] - 0s 11ms/step - loss: 4.1848 - val_loss: 3.2439
# Epoch 6/30
# 20/20 [==============================] - 0s 11ms/step - loss: 3.8528 - val_loss: 2.7350
# Epoch 7/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.5129 - val_loss: 2.5061
# Epoch 8/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2800 - val_loss: 2.6376
# Epoch 9/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.5772 - val_loss: 2.3023
# Epoch 10/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4497 - val_loss: 2.4191
# Epoch 11/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4102 - val_loss: 2.4170
# Epoch 12/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0251 - val_loss: 2.0708
# Epoch 13/30
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9818 - val_loss: 2.1079
# Epoch 14/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2454 - val_loss: 2.0960
# Epoch 15/30
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9260 - val_loss: 2.2919
# Epoch 16/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.5150 - val_loss: 2.1156
# Epoch 17/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1184 - val_loss: 2.0490
# Epoch 18/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1653 - val_loss: 2.0549
# Epoch 19/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0692 - val_loss: 2.3751
# Epoch 20/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0336 - val_loss: 1.7949
# Epoch 21/30
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9130 - val_loss: 1.7229
# Epoch 22/30
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9562 - val_loss: 2.1371
# Epoch 23/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0486 - val_loss: 1.9719
# Epoch 24/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0515 - val_loss: 2.3002
# Epoch 25/30
# 20/20 [==============================] - 0s 10ms/step - loss: 2.8251 - val_loss: 1.8752
# Epoch 26/30
# 20/20 [==============================] - 0s 11ms/step - loss: 3.3301 - val_loss: 2.0811
# At last epoch, training loss: 3.3301
# At last epoch, Validation loss: 2.0811
# 5/5 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 3ms/step - loss: 1.8080
# Train Loss: 1.8080034255981445
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2223
# Test Loss: 2.222302198410034

# %%
model4 = train_and_evaluate_model(['month','tavg','snow','tmin','tmax'], hidden_layer_sizes=[4],lstm_layer_sizes=[8,4], window_size=12, num_epochs=30, batch_size=8, learning_rate=0.01, loss='rmse')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 12, 8)             448
#
#  dropout_6 (Dropout)         (None, 12, 8)             0
#
#  lstm_7 (LSTM)               (None, 4)                 208
#
#  dropout_7 (Dropout)         (None, 4)                 0
#
#  dense_6 (Dense)             (None, 4)                 20
#
#  dense_7 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 681
# Trainable params: 681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 20/20 [==============================] - 7s 94ms/step - loss: 9.0536 - val_loss: 9.1796
# Epoch 2/30
# 20/20 [==============================] - 0s 11ms/step - loss: 8.5765 - val_loss: 8.1846
# Epoch 3/30
# 20/20 [==============================] - 0s 10ms/step - loss: 7.5338 - val_loss: 7.2230
# Epoch 4/30
# 20/20 [==============================] - 0s 12ms/step - loss: 6.6389 - val_loss: 6.6055
# Epoch 5/30
# 20/20 [==============================] - 0s 12ms/step - loss: 6.4939 - val_loss: 6.1669
# Epoch 6/30
# 20/20 [==============================] - 0s 10ms/step - loss: 5.9934 - val_loss: 5.4043
# Epoch 7/30
# 20/20 [==============================] - 0s 10ms/step - loss: 5.1854 - val_loss: 4.7484
# Epoch 8/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.5484 - val_loss: 4.2578
# Epoch 9/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.7529 - val_loss: 3.9237
# Epoch 10/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.3694 - val_loss: 3.6338
# Epoch 11/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.3707 - val_loss: 3.6155
# Epoch 12/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.8608 - val_loss: 4.4549
# Epoch 13/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.4271 - val_loss: 3.9307
# Epoch 14/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.5828 - val_loss: 3.3814
# Epoch 15/30
# 20/20 [==============================] - 0s 12ms/step - loss: 4.0728 - val_loss: 3.1832
# Epoch 16/30
# 20/20 [==============================] - 0s 11ms/step - loss: 4.3543 - val_loss: 3.3146
# Epoch 17/30
# 20/20 [==============================] - 0s 19ms/step - loss: 4.1833 - val_loss: 3.1202
# Epoch 18/30
# 20/20 [==============================] - 0s 16ms/step - loss: 3.8909 - val_loss: 3.2531
# Epoch 19/30
# 20/20 [==============================] - 0s 12ms/step - loss: 3.8299 - val_loss: 3.1490
# Epoch 20/30
# 20/20 [==============================] - 0s 10ms/step - loss: 4.4481 - val_loss: 3.1716
# Epoch 21/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.7606 - val_loss: 3.0933
# Epoch 22/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3.6811 - val_loss: 3.1134
# Epoch 23/30
# 20/20 [==============================] - 0s 10ms/step - loss: 3
150
# 18/18 [==============================] - 0s 15ms/step - loss: 7.1036 - val_loss: 4.5441
# Epoch 60/150
# 18/18 [==============================] - 0s 15ms/step - loss: 7.1534 - val_loss: 3.6250
# Epoch 61/150
# 18/18 [==============================] - 0s 15ms/step - loss: 5.9747 - val_loss: 4.0034
# Epoch 62/150
# 18/18 [==============================] - 0s 15ms/step - loss: 5.3102 - val_loss: 3.5597
# At last epoch, training loss: 5.3102
# At last epoch, Validation loss: 3.5597
# 5/5 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 1s 5ms/step - loss: 3.1375
# Train Loss: 3.137507915496826
# 2/2 [==============================] - 0s 7ms/step - loss: 5.0295
# Test Loss: 5.029480934143066

# %%
model6 = train_and_evaluate_model(['month','tavg','tmin','tmax','tc_loss_ha_United States'], hidden_layer_sizes=[8],lstm_layer_sizes=[16,8], window_size=24, num_epochs=150, batch_size=8, learning_rate=0.01, loss='mse')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 24, 16)            1408
#
#  dropout_10 (Dropout)        (None, 24, 16)            0
#
#  lstm_11 (LSTM)              (None, 8)                 800
#
#  dropout_11 (Dropout)        (None, 8)                 0
#
#  dense_9 (Dense)             (None, 8)                 72
#
#  dense_10 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 2,289
# Trainable params: 2,289
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 18/18 [==============================] - 7s 98ms/step - loss: 70.0482 - val_loss: 58.6000
# Epoch 2/150
# 18/18 [==============================] - 0s 26ms/step - loss: 49.9806 - val_loss: 47.8805
# Epoch 3/150
# 18/18 [==============================] - 0s 15ms/step - loss: 45.7244 - val_loss: 48.2624
# Epoch 4/150
# 18/18 [==============================] - 0s 15ms/step - loss: 44.8728 - val_loss: 47.9670
# Epoch 5/150
# 18/18 [==============================] - 0s 15ms/step - loss: 45.7266 - val_loss: 47.9573
# Epoch 6/150
# 18/18 [==============================] - 0s 15ms/step - loss: 45.5727 - val_loss: 48.3218
# Epoch 7/150
# 18/18 [==============================] - 0s 15ms/step - loss: 44.1588 - val_loss: 47.9951
# At last epoch, training loss: 44.1588
# At last epoch, Validation loss: 47.9951
# 5/5 [==============================] - 1s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 1s 5ms/step - loss: 44.7916
# Train Loss: 44.79160690307617
# 2/2 [==============================] - 0s 7ms/step - loss: 54.0554
# Test Loss: 54.055362701416016

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

selected_features = model3_features
X_seq_test, y_seq_test = create_sequences(test, window_size=12,seq_features=selected_features,target_variable='tavg')

# Predict temperatures using the trained model
predictions = model3.predict(X_seq_test)
print("prediction", predictions)

# Calculate evaluation metrics
mae = mean_absolute_error(y_seq_test, predictions)
mse = mean_squared_error(y_seq_test, predictions)
rmse = np.sqrt(mse)

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)

plot_predictions(y_seq_test, predictions,"Time","Average Temperatures","LSTM model with features {} with Test Data".format(selected_features))
# Out:
# 2/2 [==============================] - 0s 4ms/step
# prediction [[ 1.0354079]
#  [ 1.1268553]
#  [ 1.6440219]
#  [ 2.171288 ]
#  [ 8.327136 ]
#  [12.977594 ]
#  [15.133543 ]
#  [15.785219 ]
#  [14.749928 ]
#  [ 8.671618 ]
#  [ 3.935675 ]
#  [ 1.1095473]
#  [ 1.0367211]
#  [ 1.1144737]
#  [ 1.3672951]
#  [ 2.0470097]
#  [ 8.0734825]
#  [12.137891 ]
#  [16.162949 ]
#  [16.08537  ]
#  [13.5476   ]
#  [ 7.468086 ]
#  [ 1.7915009]
#  [ 1.2031193]
#  [ 1.036595 ]
#  [ 1.1366583]
#  [ 1.3862762]
#  [ 3.9882782]
#  [ 8.761222 ]
#  [10.938139 ]
#  [15.381571 ]
#  [16.000443 ]
#  [14.444821 ]
#  [ 9.032217 ]
#  [ 3.2815046]
#  [ 1.0754082]
#  [ 1.0330565]
#  [ 1.203469 ]
#  [ 1.3909667]
#  [ 1.6513261]
#  [ 4.056907 ]
#  [ 9.871853 ]
#  [13.912839 ]
#  [16.076754 ]
#  [12.715374 ]
#  [ 5.256071 ]
#  [ 2.3455734]
#  [ 1.1036898]]
# Mean Absolute Error (MAE): 1.8434060873587927
# Mean Squared Error (MSE): 5.095432238407702
# Root Mean Squared Error (RMSE): 2.2573064121664346

# %%
model7_features=['month','tavg','tmax','tmin','tc_loss_ha_average_scaled']
model7 = train_and_evaluate_model(model7_features, hidden_layer_sizes=[],lstm_layer_sizes=[8,8], window_size=12, num_epochs=50, batch_size=8, learning_rate=0.005,loss='mae')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 12, 8)             448
#
#  dropout_12 (Dropout)        (None, 12, 8)             0
#
#  lstm_13 (LSTM)              (None, 8)                 544
#
#  dropout_13 (Dropout)        (None, 8)                 0
#
#  dense_11 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 1,001
# Trainable params: 1,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 20/20 [==============================] - 6s 78ms/step - loss: 7.1572 - val_loss: 6.9819
# Epoch 2/50
# 20/20 [==============================] - 0s 11ms/step - loss: 6.3565 - val_loss: 6.1731
# Epoch 3/50
# 20/20 [==============================] - 0s 10ms/step - loss: 6.0127 - val_loss: 5.8744
# Epoch 4/50
# 20/20 [==============================] - 0s 10ms/step - loss: 5.7761 - val_loss: 5.3694
# Epoch 5/50
# 20/20 [==============================] - 0s 10ms/step - loss: 5.0785 - val_loss: 4.8438
# Epoch 6/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.6138 - val_loss: 4.2919
# Epoch 7/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.1951 - val_loss: 3.9172
# Epoch 8/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.0048 - val_loss: 3.4756
# Epoch 9/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.5346 - val_loss: 3.2244
# Epoch 10/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2458 - val_loss: 2.8948
# Epoch 11/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2748 - val_loss: 2.6640
# Epoch 12/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.0814 - val_loss: 2.6178
# Epoch 13/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.6803 - val_loss: 2.4989
# Epoch 14/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5687 - val_loss: 2.4406
# Epoch 15/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4513 - val_loss: 2.2677
# Epoch 16/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4652 - val_loss: 2.0588
# Epoch 17/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3000 - val_loss: 2.0625
# Epoch 18/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2940 - val_loss: 1.7506
# Epoch 19/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9903 - val_loss: 2.0862
# Epoch 20/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1434 - val_loss: 1.8708
# Epoch 21/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1330 - val_loss: 1.6103
# Epoch 22/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3046 - val_loss: 1.5426
# Epoch 23/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.7564 - val_loss: 1.5574
# Epoch 24/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0159 - val_loss: 1.4554
# Epoch 25/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1214 - val_loss: 1.4765
# Epoch 26/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1153 - val_loss: 1.7815
# Epoch 27/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2295 - val_loss: 1.5692
# Epoch 28/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9882 - val_loss: 1.3602
# Epoch 29/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0080 - val_loss: 1.5746
# Epoch 30/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9553 - val_loss: 1.4270
# Epoch 31/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.8858 - val_loss: 1.3888
# Epoch 32/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.8854 - val_loss: 1.4493
# Epoch 33/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.8921 - val_loss: 1.3565
# Epoch 34/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9126 - val_loss: 1.5411
# Epoch 35/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9570 - val_loss: 1.5205
# Epoch 36/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9598 - val_loss: 1.3493
# Epoch 37/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.6461 - val_loss: 1.6827
# Epoch 38/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9253 - val_loss: 1.3518
# Epoch 39/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.8733 - val_loss: 1.3532
# Epoch 40/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.7828 - val_loss: 1.2481
# Epoch 41/50
# 20/20 [==============================] - 0s 14ms/step - loss: 1.7450 - val_loss: 1.3730
# Epoch 42/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.8642 - val_loss: 1.3090
# Epoch 43/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.7128 - val_loss: 1.2597
# Epoch 44/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.9213 - val_loss: 1.6697
# Epoch 45/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.8788 - val_loss: 1.2780
# At last epoch, training loss: 1.8788
# At last epoch, Validation loss: 1.2780
# 5/5 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1989
# Train Loss: 1.1989307403564453
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5362
# Test Loss: 1.5361968278884888

# %%
model8_features=['month','tavg_scaled','tmax_scaled','tmin_scaled','tc_loss_ha_average_scaled']
model8 = train_and_evaluate_model(model7_features, hidden_layer_sizes=[],lstm_layer_sizes=[8,8], window_size=12, num_epochs=50, batch_size=8, learning_rate=0.005,loss='mae')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 12, 8)             448
#
#  dropout_14 (Dropout)        (None, 12, 8)             0
#
#  lstm_15 (LSTM)              (None, 8)                 544
#
#  dropout_15 (Dropout)        (None, 8)                 0
#
#  dense_12 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 1,001
# Trainable params: 1,001
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 20/20 [==============================] - 7s 83ms/step - loss: 6.8973 - val_loss: 6.7280
# Epoch 2/50
# 20/20 [==============================] - 0s 12ms/step - loss: 6.2546 - val_loss: 6.2239
# Epoch 3/50
# 20/20 [==============================] - 0s 10ms/step - loss: 6.0560 - val_loss: 5.9487
# Epoch 4/50
# 20/20 [==============================] - 0s 10ms/step - loss: 5.8088 - val_loss: 5.5630
# Epoch 5/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.9651 - val_loss: 4.7637
# Epoch 6/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.2483 - val_loss: 4.2805
# Epoch 7/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.0282 - val_loss: 4.2354
# Epoch 8/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.0254 - val_loss: 3.8900
# Epoch 9/50
# 20/20 [==============================] - 0s 9ms/step - loss: 3.6858 - val_loss: 3.6836
# Epoch 10/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.3650 - val_loss: 3.3690
# Epoch 11/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.3692 - val_loss: 2.9515
# Epoch 12/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.8750 - val_loss: 2.8198
# Epoch 13/50
# 20/20 [==============================] - 0s 9ms/step - loss: 2.5813 - val_loss: 2.5571
# Epoch 14/50
# 20/20 [==============================] - 0s 9ms/step - loss: 2.6857 - val_loss: 2.5304
# Epoch 15/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.6150 - val_loss: 2.2888
# Epoch 16/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3994 - val_loss: 2.0357
# Epoch 17/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1080 - val_loss: 1.8844
# Epoch 18/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0500 - val_loss: 1.8368
# Epoch 19/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.8104 - val_loss: 1.7202
# Epoch 20/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0851 - val_loss: 1.7201
# Epoch 21/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1115 - val_loss: 1.5427
# Epoch 22/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0544 - val_loss: 1.4735
# Epoch 23/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.8516 - val_loss: 1.4803
# Epoch 24/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.0227 - val_loss: 1.4001
# Epoch 25/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.9012 - val_loss: 1.5271
# Epoch 26/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.8588 - val_loss: 1.5716
# Epoch 27/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.9786 - val_loss: 1.7247
# Epoch 28/50
# 20/20 [==============================] - 0s 9ms/step - loss: 2.1580 - val_loss: 1.4229
# Epoch 29/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.9299 - val_loss: 1.6812
# At last epoch, training loss: 1.9299
# At last epoch, Validation loss: 1.6812
# 5/5 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4804
# Train Loss: 1.4803911447525024
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0851
# Test Loss: 2.085090398788452
